# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/Automobile_data (1).csv')
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data=data.replace('?',0)

# %%
data=data.replace('two',2)
data=data.replace('four',4)
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 0  alfa-romero       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#      num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0               2  convertible          rwd           front        88.6  ...
# ...

# %%
CompanyName = data['make'].apply(lambda x : x.split(' ')[0])
data.insert(3,"CompanyName",CompanyName)

# %%
data.drop(['make'],axis=1,inplace=True)

# %%
data.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
No_of_doors=data['num-of-doors']
data.insert(6,"No_of_doors",No_of_doors)

# %%
data.drop(['num-of-doors'],axis=1,inplace=True)

# %%
data
# Out:
#      symboling normalized-losses  CompanyName fuel-type aspiration  \
# 0            3                 0  alfa-romero       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#      No_of_doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
data.CompanyName = data.CompanyName.str.lower()
def replace_item(a,b):
  data.CompanyName.replace(a,b,inplace=True)

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, CompanyName, fuel-type, aspiration, No_of_doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
def get_variable_type(element) :
   
    if element==0:
        return "Not Known"
    elif element < 20 and element!=0 :
        return "Categorical"
    elif element >= 20 and element!=0 :
        return "Contineous"
    
def predict_variable_type(metadata_matrix):
    metadata_matrix["Variable_Type"] = metadata_matrix["Unique values_Count"].apply(get_variable_type).astype(str)
    metadata_matrix["frequency"] = metadata_matrix["Null_Count"] - metadata_matrix["Null_Count"]
    metadata_matrix["frequency"].astype(int)
    return metadata_matrix 

def get_meta_data(dataframe) :
    
    metadata_matrix = pd.DataFrame({
                    'Datatype' : dataframe.dtypes.astype(str),
                    'Non_Null_Count': dataframe.count(axis = 0).astype(int),
                    'Null_Count': dataframe.isnull().sum().astype(int),
                    'Null_Percentage': dataframe.isnull().sum()/len(dataframe) * 100,
                    'Unique values_Count': dataframe.nunique().astype(int)
                     })
    
    metadata_matrix = predict_variable_type(metadata_matrix)
    return metadata_matrix

def list_potential_categorical_type(dataframe,data) :
    metadata_matrix_categorical = dataframe[dataframe["Variable_Type"] == "Categorical"]
    
    length = len(metadata_matrix_categorical)
    if length == 0 :
        print("Aucune colonne catégorique dans un jeu de données donné.")  
    else :    
        metadata_matrix_categorical = metadata_matrix_categorical.filter(["Datatype","Unique values_Count"])
        metadata_matrix_categorical.sort_values(["Unique values_Count"], axis=0,ascending=False, inplace=True)
        col_to_check = metadata_matrix_categorical.index.tolist()
        name_list = []
        values_list = []
        
        for name in col_to_check :
            name_list.append(name)
            values_list.append(data[name].unique())
        
        temp = pd.DataFrame({"index":name_list,"Unique values":values_list})
        metadata_matrix_categorical = metadata_matrix_categorical.reset_index()
        metadata_matrix_categorical = pd.merge(metadata_matrix_categorical,temp,how='inner',on='index')
        display(metadata_matrix_categorical.set_index("index"))

# %%
data.No_of_doors.replace(0,2)
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 200    4
# 201    4
# 202    4
# 203    4
# 204    4
# Name: No_of_doors, Length: 205, dtype: int64

# %%
data.No_of_doors.unique()
# Out:
# array([2, 4, 0])

# %%
metadata = get_meta_data(data)
list_potential_categorical_type(metadata,data)
# Out:
#                  Datatype  Unique values_Count  \
# index
# fuel-system        object                    8
# engine-type        object                    7
# num-of-cylinders   object                    7
# symboling           int64                    6
# body-style         object                    5
# No_of_doors         int64                    3
# drive-wheels       object                    3
# fuel-type          object                    2
# aspiration         object                    2
# engine-location    object                    2
#
#                                                     Unique values
# index
# fuel-system        [mpfi, 2bbl, mfi, 1bbl, spfi, 4bbl, idi, spdi]
# engine-type              [dohc, ohcv, ohc, l, rotor, ohcf, dohcv]
# num-of-cylinders          [4, six, five, three, twelve, 2, eight]
# symboling                                    [3, 1, 2, 0, -1, -2]
# body-style        [convertible, hatchback, sedan, wagon, hardtop]
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   CompanyName        205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   No_of_doors        205 non-null    int64
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data['price']=data['price'].astype(float)
plt.title('Car price distribution')
sns.boxplot(y=data.price)
plt.ylabel('Price')
plt.show()

# %%
data.price.describe()
# Out:
# count      205.000000
# mean     12949.429268
# std       8079.043284
# min          0.000000
# 25%       7689.000000
# 50%      10198.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
data['horsepower']=data['horsepower'].astype(int)
sns.boxplot(y=data.horsepower)
plt.show()
print(data.horsepower.describe())
# Out:
# count    205.000000
# mean     103.239024
# std       40.832470
# min        0.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
sns.distplot(data.price)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
group=pd.DataFrame(data.groupby(by=['body-style']).agg({'count'}))
group=group.iloc[:,[1]]
group
# Out:
#             normalized-losses
#                         count
# body-style
# convertible                 6
# hardtop                     8
# hatchback                  70
# sedan                      96
# wagon                      25

# %%
group.rename(columns={'normalized-losses':'normalized','body-style':'body'},inplace=True)
list1=group.normalized.values.tolist()
list1
# Out:
# [[6], [8], [70], [96], [25]]

# %%
plt.xticks(rotation=90)
seq=data['CompanyName'].value_counts(ascending=False).index
sns.countplot(x='CompanyName',data=data,order=seq)
plt.show()

# %%
plt.xticks(rotation=90)
seq=data['body-style'].value_counts(ascending=False).index
sns.countplot(x='body-style',data=data,order=seq)
plt.show()

# %%
data.plot.scatter(x='horsepower',y='engine-size',c='green')

# %%
data.plot.scatter(x='horsepower',y='price',c='blue')

# %%
group.plot.pie(y='normalized', figsize=(5, 5),autopct='%1.1f%%', startangle=180)
plt.title('Body-style distribution')
# Out:
# Text(0.5, 1.0, 'Body-style distribution')

# %%
group2=data.groupby(by=['No_of_doors']).agg({'count'})
list2=group2.symboling.values.tolist()
plot=group2.plot.pie(y='symboling', explode=(1,0,0),shadow=True,figsize=(5, 5),autopct='%1.1f%%', startangle=180)
plot.axis('equal')
plt.title('No.of Doors for cars')
# Out:
# Text(0.5, 1.0, 'No.of Doors for cars')

# %%
def heatmap(x,y,df):
  sns.heatmap(df.corr(),cmap="OrRd",annot=True)
  plt.show()

# %%
heatmap(20,10,data)

# %%
collist=['horsepower','city-mpg','highway-mpg','engine-size']
heatmap(20,10,data.filter(collist))

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='fuel-type',y='price',data=data)
plt.subplot(2,3,2)
order=data['fuel-type'].value_counts(ascending=False).index
sns.countplot(x='fuel-type',data=data,order=order)

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='body-style',y='price',data=data)
plt.subplot(2,3,2)
order=data['body-style'].value_counts(ascending=False).index
sns.countplot(x='body-style',data=data,order=order)

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='engine-type',y='price',data=data)
plt.subplot(2,3,2)
order=data['engine-type'].value_counts(ascending=False).index
sns.countplot(x='engine-type',data=data,order=order)

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='symboling',y='price',data=data)
plt.subplot(2,3,2)
order=data['symboling'].value_counts(ascending=False).index
sns.countplot(x='symboling',data=data,order=order)

# %%
collist=['height','length','width','price']
heatmap(20,10,data.filter(collist))

# %%
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

# %%
data['peak-rpm']=data['peak-rpm'].astype(int)
outliers = find_outliers_IQR(data['peak-rpm'])
print("number of outliers: "+ str(len(outliers)))
print("max outlier value: "+ str(outliers.max()))
print("min outlier value: "+ str(outliers.min()))
# Out:
# number of outliers: 4
# max outlier value: 6600
# min outlier value: 0

# %%
def drop_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   not_outliers = df[~((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   outliers_dropped = outliers.dropna().reset_index()

   return outliers_dropped

# %%
upper_limit = data['peak-rpm'].mean() + 3*data['peak-rpm'].std()
print(upper_limit)
lower_limit = data['peak-rpm'].mean() - 3*data['peak-rpm'].std()
print(lower_limit)
# Out:
# 7159.3181672533465
# 2991.4135400637265

# %%
data.describe()['peak-rpm']
# Out:
# count     205.000000
# mean     5075.365854
# std       694.650771
# min         0.000000
# 25%      4800.000000
# 50%      5200.000000
# 75%      5500.000000
# max      6600.000000
# Name: peak-rpm, dtype: float64

# %%
random=np.random.choice(data['peak-rpm'],replace=False,size=10)
random
# Out:
# array([5400, 6000, 4350, 6000, 5250, 4800, 4800, 4800, 5000, 4500])

# %%
data.groupby('body-style',group_keys=False).apply(lambda x:x.sample(frac=0.29))
# Out:
#      symboling normalized-losses    CompanyName fuel-type aspiration  \
# 128          3                 0        porsche       gas        std
# 72           3               142  mercedes-benz       gas        std
# 69           0                93  mercedes-benz    diesel      turbo
# 74           1                 0  mercedes-benz       gas        std
# 29           3               145          dodge       gas      turbo
# 34           1               101          honda       gas        std
# 104          3               194         nissan       gas        std
# 52           1               104          mazda       gas        std
# 24           1               148          dodge       gas        std
# 18           2               121      chevrolet       gas        std
# 55           3               150          mazda       gas        std
# 106          1               231         nissan       gas        std
# 152          1                74         toyota       gas        std
# ...

# %%
sns.pairplot(data)

# %%
sns.distplot(data['price'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.lmplot(x="city-mpg", y="highway-mpg", data=data);

# %%
data['horsepower']=data['horsepower'].astype(int)
data['engine-size']=data['engine-size'].astype(int)
sns.lmplot(x="horsepower", y="engine-size", data=data);

# %%
plt.title('Symboling Histogram')
sns.countplot(data.symboling, palette=("cubehelix"))
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.title('Symboling vs Price')
sns.boxplot(x=data.symboling, y=data.price, palette=("cubehelix"))

# %%
plt.title('Engine Type Histogram')
sns.countplot(data['engine-type'], palette=("Blues_d"))
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.title('Engine Type vs Price')
sns.boxplot(x=data['engine-type'], y=data['price'], palette=("PuBuGn"))

# %%
df = pd.DataFrame(data.groupby(['engine-type'])['price'].mean().sort_values(ascending = False))
df.plot.bar(figsize=(8,6))
plt.title('Engine Type vs Average Price')
plt.show()

# %%
df = pd.DataFrame(data.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Company Name vs Average Price')
plt.show()

# %%
df = pd.DataFrame(data.groupby(['fuel-type'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Fuel Type vs Average Price')
plt.show()

# %%
df = pd.DataFrame(data.groupby(['body-style'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Car Type vs Average Price')
plt.show()

# %%
def plot_count(x,fig):
    plt.subplot(4,2,fig)
    plt.title(x+' Histogram')
    sns.countplot(data[x],palette=("magma"))
    plt.subplot(4,2,(fig+1))
    plt.title(x+' vs Price')
    sns.boxplot(x=data[x], y=data.price, palette=("magma"))
    
plt.figure(figsize=(15,20))

plot_count('engine-location', 1)
plot_count('num-of-cylinders', 3)
plot_count('fuel-system', 5)
plot_count('drive-wheels', 7)

plt.tight_layout()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(data[x],data['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

scatter('length', 1)
scatter('width', 2)
scatter('height', 3)
scatter('curb-weight', 4)

plt.tight_layout()

# %%
plt.figure(figsize=(25, 6))

df = pd.DataFrame(data.groupby(['fuel-system','drive-wheels'])['price'].mean().unstack(fill_value=0))
df.plot.bar()
plt.title('Car Range vs Average Price')
plt.show()

# %%
sns.violinplot(data=data, x="price", y="body-style")

# %%
sns.violinplot(data=data, x="horsepower", y="body-style")

# %%
data['price'].plot.hist(bins=12, alpha=0.5)
